# %% [markdown]
# <a href="https://colab.research.google.com/github/StillWork/6FM1/blob/main/260412.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
x+5
# Out:
# 8

# %%
x*10
# Out:
# 30
