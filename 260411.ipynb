# %% [markdown]
# <a href="https://colab.research.google.com/github/StillWork/6FM1/blob/main/260411.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
y=7
x+y
# Out:
# 10

# %%
x*4
# Out:
# 12
